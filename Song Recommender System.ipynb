# %% [markdown]
# # Import Necessary libraries

# %%
# %matplotlib inline

import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import time
import joblib
import Recommenders as Recommenders
import Evaluation as Evaluation

# %% [markdown]
# # Import datasets

# %%
song_df1=pd.read_csv('triplets_file/triplets_file.csv')
song_df2=pd.read_csv('song_data/song_data.csv')

# %% [markdown]
# # Exploring the datasets

# %%
song_df1.head()
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1

# %%
song_df2.head()
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %% [markdown]
# # Performing left-join operation on dataframes

# %%
song_df=pd.merge(song_df1,song_df2.drop_duplicates(['song_id']),how="left",on="song_id" )

# %%
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
len(song_df)
# Out:
# 2000000

# %%
song_df=song_df.sample(20000)

# %% [markdown]
# # Store the song name as "*title* - *artist name*" in a new column

# %%
song_df['song_name']=song_df['title'].map(str)+" - "+song_df['artist_name']
song_df.head()
# Out:
#                                           user_id             song_id  \
# 1348300  f38c1490438e2df9c7affcfee4b7644077d7ae2a  SOCBSZW12AB01891C1
# 493973   9a95678196cc9d20f4f3ff7a4e9595dd4a6b7ab2  SOHHHYJ12AB0184D60
# 229141   44e0cf636b7f1b6fe5269e557927eb53ef29b730  SOMHWDR12A8C1380BA
# 1141360  c6f2c209d305694a60cf66251dba4223ee1f9c0c  SOFRCGW12A81C21EA6
# 850432   98e8cd9a8e4f0255a511a380a3ad0e3cc94c7f56  SOCBWRP12A8C1311DB
#
#          listen_count                 title  \
# 1348300             3                  XRDS
# 493973              1            Ocean View
# 229141              1  Ocean Breathes Salty
# 1141360             2     Hey There Delilah
# 850432              1                   Hey
#
#                                         release        artist_name  year  \
# 1348300                            Ritual Noise           Covenant     0
# 493973                        Goodbye Manhattan  Pieces Of A Dream  2007
# 229141   Good News For People Who Love Bad News       Modest Mouse  2004
# 1141360        Now That's What I Call Music! 68    Plain White T's  2005
# 850432       Wave Of Mutilation: Best Of Pixies             Pixies  1989
#
#                                    song_name
# 1348300                      XRDS - Covenant
# 493973        Ocean View - Pieces Of A Dream
# 229141   Ocean Breathes Salty - Modest Mouse
# 1141360  Hey There Delilah - Plain White T's
# 850432                          Hey - Pixies

# %% [markdown]
# # Calculating percentage listen count for each song

# %%
song_grouped=song_df.groupby(['song_name']).agg({'listen_count':'count'}).reset_index()
listen_count_sum=song_grouped['listen_count'].sum()
song_grouped['percentage']=song_grouped['listen_count'].div(listen_count_sum)*100
song_grouped
# Out:
#                                          song_name  listen_count  percentage
# 0                         #40 - DAVE MATTHEWS BAND             1       0.005
# 1                              & Down - Boys Noize             9       0.045
# 2                        ' Cello Song - Nick Drake             4       0.020
# 3                    'Round Midnight - Miles Davis             1       0.005
# 4           'Til We Die (Album Version) - Slipknot             6       0.030
# ...                                            ...           ...         ...
# 7263                 sun drums and soil - Four Tet             1       0.005
# 7264     teachme (Album Version) - Musiq Soulchild             1       0.005
# 7265             you were there with me - Four Tet             1       0.005
# 7266  ¡Viva La Gloria! (Album Version) - Green Day             1       0.005
# 7267       ¿Lo Ves? [Piano Y Voz] - Alejandro Sanz             1       0.005
#
# [7268 rows x 3 columns]

# %% [markdown]
# # Total number of users in the selected part of the dataset

# %%
users=song_df['user_id'].unique()
len(users)
# Out:
# 15507

# %% [markdown]
# # Total number of songs in the selected part of the dataset

# %%
songs = song_df['song_name'].unique()
len(songs)
# Out:
# 7268

# %% [markdown]
# # Train-test split

# %%
train_data,test_data=train_test_split(song_df,test_size=0.2,random_state=0)
train_data.head()
# Out:
#                                           user_id             song_id  \
# 167978   03f7e4ac0d94229253aa4c5f6801e23d268ba1aa  SOPPPWN12A8C135DCD
# 1925651  20215b21d188499c7e4a3ab833f52ecef3be1bdd  SORXEUZ12AC3DF6E3F
# 339762   532ba1de8872c56d2bc02f749f7ca10160ef2008  SOKCRPL12AB018D1A2
# 1969526  e09032fff6dd20acb3771c2209b1a46e55d2cae7  SOOABBO12A6701DFDA
# 739423   155dfdd4cf9acb4d66423ae1e9013f007ce813fa  SONAZWN12A8151C957
#
#          listen_count                title                            release  \
# 167978              1            Milkshake                                 LP
# 1925651             2         Bend & Flush  All The Filth! (With Extra Filth)
# 339762              1    Someone's Missing                    Congratulations
# 1969526             1                Flake               Brushfire Fairytales
# 739423              1  White Winter Hymnal                White Winter Hymnal
#
#           artist_name  year                          song_name
# 167978      Holy Fuck  2007              Milkshake - Holy Fuck
# 1925651    Pork Dukes     0          Bend & Flush - Pork Dukes
# 339762           MGMT  2010           Someone's Missing - MGMT
# 1969526  Jack Johnson  2000               Flake - Jack Johnson
# 739423    Fleet Foxes  2008  White Winter Hymnal - Fleet Foxes

# %% [markdown]
# # Creating popularity based recommender model

# %%
popularity_recommender = Recommenders.popularity_recommender_py()
popularity_recommender.create(train_data, 'user_id', 'song_name')

# %%
random_user=np.random.choice(users)
popularity_recommender.recommend(random_user)
# Out:
#                                        user_id  \
# 4754  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 6026  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 1369  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 6571  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 4517  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 2319  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 4747  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 1795  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 2408  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 1468  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
#
#                                               song_name  score  Rank
# 4754                           Sehr kosmisch - Harmonia     61   1.0
# 6026                                       Undo - Björk     59   2.0
# 1369  Dog Days Are Over (Radio Edit) - Florence + Th...     54   3.0
# 6571                     You're The One - Dwight Yoakam     51   4.0
# 4517                            Revelry - Kings Of Leon     45   5.0
# 2319                           Hey_ Soul Sister - Train     44   6.0
# 4747                              Secrets - OneRepublic     44   7.0
# 1795                     Fireflies - Charttraxx Karaoke     39   8.0
# 2408  Horn Concerto No. 4 in E flat K495: II. Romanc...     39   9.0
# 1468                Drop The World - Lil Wayne / Eminem     38  10.0

# %%
random_user2=np.random.choice(users)
popularity_recommender.recommend(random_user2)
# Out:
#                                        user_id  \
# 4754  46da7b0cca93a98e88a6366c4670691f37d1761f
# 6026  46da7b0cca93a98e88a6366c4670691f37d1761f
# 1369  46da7b0cca93a98e88a6366c4670691f37d1761f
# 6571  46da7b0cca93a98e88a6366c4670691f37d1761f
# 4517  46da7b0cca93a98e88a6366c4670691f37d1761f
# 2319  46da7b0cca93a98e88a6366c4670691f37d1761f
# 4747  46da7b0cca93a98e88a6366c4670691f37d1761f
# 1795  46da7b0cca93a98e88a6366c4670691f37d1761f
# 2408  46da7b0cca93a98e88a6366c4670691f37d1761f
# 1468  46da7b0cca93a98e88a6366c4670691f37d1761f
#
#                                               song_name  score  Rank
# 4754                           Sehr kosmisch - Harmonia     61   1.0
# 6026                                       Undo - Björk     59   2.0
# 1369  Dog Days Are Over (Radio Edit) - Florence + Th...     54   3.0
# 6571                     You're The One - Dwight Yoakam     51   4.0
# 4517                            Revelry - Kings Of Leon     45   5.0
# 2319                           Hey_ Soul Sister - Train     44   6.0
# 4747                              Secrets - OneRepublic     44   7.0
# 1795                     Fireflies - Charttraxx Karaoke     39   8.0
# 2408  Horn Concerto No. 4 in E flat K495: II. Romanc...     39   9.0
# 1468                Drop The World - Lil Wayne / Eminem     38  10.0

# %% [markdown]
# # Creating item-similarity based recommender model

# %%
item_similarity_recommender=Recommenders.item_similarity_recommender_py()
item_similarity_recommender.create(train_data,'user_id','song_name')

# %%
user_items = item_similarity_recommender.get_user_items(random_user)
#
print("------------------------------------------------------------------------------------")
print("Training data songs for the user userid: %s:" % random_user)
print("------------------------------------------------------------------------------------")

for user_item in user_items:
    print(user_item)

print("----------------------------------------------------------------------")
print("Recommendation process going on:")
print("----------------------------------------------------------------------")

#Recommend songs for the user using personalized model
item_similarity_recommender.recommend(random_user)
# Out:
# ------------------------------------------------------------------------------------
# Training data songs for the user userid: c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a:
# ------------------------------------------------------------------------------------
# White Shadows - Coldplay
# ----------------------------------------------------------------------
# Recommendation process going on:
# ----------------------------------------------------------------------
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 6617
# Non zero values in cooccurence_matrix :3
#                                     user_id  \
# 0  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 1  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 2  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 3  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 4  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 5  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 6  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 7  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 8  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
# 9  c3f324c4daaf525dc7323b6e54e3cfb18fcdf32a
#
#                                            song_name     score rank
# 0                                      Ego - Beyoncé  0.200000    1
# 1             A Rush Of Blood To The Head - Coldplay  0.142857    2
# 2                       Serve The Servants - Nirvana  0.000000    3
# 3                            Method Man - Method Man  0.000000    4
# 4                           Lemme Get That - Rihanna  0.000000    5
# 5                              It's Tricky - RUN-DMC  0.000000    6
# 6  Tango del Pecado - Calle 13 Featuring Bajofond...  0.000000    7
# 7                              When We Dance - Sting  0.000000    8
# 8  All These Things I Hate [revolve Around Me] [a...  0.000000    9
# 9                             The Pulse - Digitalism  0.000000   10

# %%
user_items = item_similarity_recommender.get_user_items(random_user2)
#
print("------------------------------------------------------------------------------------")
print("Training data songs for the user userid: %s:" % random_user2)
print("------------------------------------------------------------------------------------")

for user_item in user_items:
    print(user_item)

print("----------------------------------------------------------------------")
print("Recommendation process going on:")
print("----------------------------------------------------------------------")

#Recommend songs for the user using personalized model
item_similarity_recommender.recommend(random_user2)
# Out:
# ------------------------------------------------------------------------------------
# Training data songs for the user userid: 46da7b0cca93a98e88a6366c4670691f37d1761f:
# ------------------------------------------------------------------------------------
# The Way Things Go - Octopus Project
# ----------------------------------------------------------------------
# Recommendation process going on:
# ----------------------------------------------------------------------
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 6617
# Non zero values in cooccurence_matrix :9
#                                     user_id  \
# 0  46da7b0cca93a98e88a6366c4670691f37d1761f
# 1  46da7b0cca93a98e88a6366c4670691f37d1761f
# 2  46da7b0cca93a98e88a6366c4670691f37d1761f
# 3  46da7b0cca93a98e88a6366c4670691f37d1761f
# 4  46da7b0cca93a98e88a6366c4670691f37d1761f
# 5  46da7b0cca93a98e88a6366c4670691f37d1761f
# 6  46da7b0cca93a98e88a6366c4670691f37d1761f
# 7  46da7b0cca93a98e88a6366c4670691f37d1761f
# 8  46da7b0cca93a98e88a6366c4670691f37d1761f
# 9  46da7b0cca93a98e88a6366c4670691f37d1761f
#
#                                            song_name     score rank
# 0                    Heavyweight - Infected Mushroom  0.100000    1
# 1                                 Skyscraper - Train  0.090909    2
# 2                       Caring Is Creepy - The Shins  0.083333    3
# 3  Just The Two Of Us (WSM Compilation Edit) - Gr...  0.083333    4
# 4                  Responsible Stu - Octopus Project  0.076923    5
# 5                               If It's Love - Train  0.076923    6
# 6                            Day 'N' Nite - Kid Cudi  0.071429    7
# 7                           Sehr kosmisch - Harmonia  0.014286    8
# 8                       Serve The Servants - Nirvana  0.000000    9
# 9                            Method Man - Method Man  0.000000   10

# %% [markdown]
# # Recommending similar songs

# %%
item_similarity_recommender.get_similar_items(['Secrets - OneRepublic'])
# Out:
# no. of unique songs in the training set: 6617
# Non zero values in cooccurence_matrix :16
#   user_id                                      song_name     score rank
# 0                   The Sporting Life - The Decemberists  0.022727    1
# 1                 Face To Face (Demon Remix) - Daft Punk  0.022222    2
# 2                   One And Only - Mariah Carey / Twista  0.022222    3
# 3                                   Kickstarts - Example  0.022222    4
# 4          Satisfaction - Benny Benassi Presents The Biz  0.022222    5
# 5                          She Loves You - Peter Sellers  0.021739    6
# 6                            Wie Jetzt - Dynamite Deluxe  0.021739    7
# 7                          The World - Empire Of The Sun  0.021277    8
# 8                         How You Remind Me - Nickelback  0.018868    9
# 9                       A-Punk (Album) - Vampire Weekend  0.018519   10

# %%
song = 'White Shadows - Coldplay'
item_similarity_recommender.get_similar_items([song])
# Out:
# no. of unique songs in the training set: 6617
# Non zero values in cooccurence_matrix :3
#   user_id                                          song_name     score rank
# 0                                              Ego - Beyoncé  0.200000    1
# 1                     A Rush Of Blood To The Head - Coldplay  0.142857    2
# 2                               Serve The Servants - Nirvana  0.000000    3
# 3                                    Method Man - Method Man  0.000000    4
# 4                                   Lemme Get That - Rihanna  0.000000    5
# 5                                      It's Tricky - RUN-DMC  0.000000    6
# 6          Tango del Pecado - Calle 13 Featuring Bajofond...  0.000000    7
# 7                                      When We Dance - Sting  0.000000    8
# 8          All These Things I Hate [revolve Around Me] [a...  0.000000    9
# 9                                     The Pulse - Digitalism  0.000000   10
